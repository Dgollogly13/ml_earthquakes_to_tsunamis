# %%
# Importing dependencies 

import pandas as pd
import numpy as np

# %%
# Import dataset for analysis 

earthquake_data = pd.read_csv("data/earthquake_query.csv")
earthquake_data.head(10)
# Out:
#        date                  datetime  latitude   longitude   depth  mag  \
# 0   1/28/20  2020-01-28T19:10:24.922Z   19.4210  -78.762700   14.80  7.7
# 1  11/14/19  2019-11-14T16:17:40.578Z    1.6213  126.415600   33.00  7.1
# 2   7/14/19  2019-07-14T09:10:51.523Z   -0.5858  128.034000   18.98  7.2
# 3    7/6/19  2019-07-06T03:19:53.040Z   35.7695 -117.599333    8.00  7.1
# 4   6/24/19  2019-06-24T02:53:39.830Z   -6.4078  129.169200  212.00  7.3
# 5   6/15/19  2019-06-15T22:55:04.130Z  -30.6441 -178.099500   46.00  7.3
# 6   5/26/19  2019-05-26T07:41:15.073Z   -5.8119  -75.269700  122.57  8.0
# 7   5/14/19  2019-05-14T12:58:25.939Z   -4.0510  152.596700   10.00  7.6
# 8    5/6/19  2019-05-06T21:19:37.983Z   -6.9746  146.449400  146.00  7.1
# 9    3/1/19  2019-03-01T08:50:42.591Z  -14.7131  -70.154600  267.00  7.0
#
#   magType   nst   gap     dmin  ...                   updated  \
# 0     mww   NaN  26.0  1.66300  ...  2020-02-09T04:07:20.128Z
# ...

# %%
tsunami_data = pd.read_csv("data/Tsunami_Events.csv", skiprows=1)
tsunami_data.head(10)
# Out:
#          Date  Year  Month   Day  Hour   Min   Sec  Val  Code  \
# 0  1920-01-29  1920    1.0  29.0   NaN   NaN   NaN    1     1
# 1  1920-02-02  1920    2.0   2.0  11.0  22.0  18.0    1     1
# 2  1920-08-20  1920    8.0  20.0  16.0  15.0  38.0    3     1
# 3    1920-08-  1920    8.0   NaN   NaN   NaN   NaN   -1     1
# 4  1920-09-20  1920    9.0  20.0  14.0  39.0   NaN    3     1
# 5  1920-12-16  1920   12.0  16.0  12.0   5.0  53.0    0     1
# 6  1920-12-18  1920   12.0  18.0   2.0   1.0  57.0    1     1
# 7  1921-05-14  1921    5.0  14.0  11.0  17.0  45.0    2     1
# 8    1921-8-4  1921    8.0   4.0   NaN   NaN   NaN    3     1
# 9  1921-09-11  1921    9.0  11.0   4.0   1.0  38.0    4     1
#
#    Earthquake Code  ... Injuries Approx  Damage in $Millions Damage Approx  \
# 0              NaN  ...             NaN                  NaN           NaN
# 1              7.7  ...             NaN                  NaN           NaN
# ...
